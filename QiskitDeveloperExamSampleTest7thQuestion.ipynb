# %% [markdown]
# ## Question 7: Answer is B

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, Aer, execute

from qiskit.quantum_info import Statevector # the state vector of the required qubits is generated
from qiskit.visualization import plot_bloch_multivector, plot_histogram, plot_state_qsphere # plot the qubits in a qsphere


import numpy as np
from numpy import pi
import math
from math import sqrt

import matplotlib as mpl
# %matplotlib inline

# %%
import qiskit
qiskit.__version__
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.21.0', 'qiskit-aer': '0.10.4', 'qiskit-ignis': '0.6.0', 'qiskit-ibmq-provider': '0.19.2', 'qiskit': '0.37.0', 'qiskit-nature': None, 'qiskit-finance': None, 'qiskit-optimization': None, 'qiskit-machine-learning': None}

# %%
qc = QuantumCircuit(3)
qc.z(0)

qc.s(1)
qc.s(1)

qc.t(2)
qc.t(2)
qc.t(2)
qc.t(2)

qc.draw()

# %% [markdown]
# S-gate induces a 𝜋/2 phase, and is sometimes called the $\sqrt{Z}$ gate.
#
# This is a Clifford gate and a square-root of Pauli-Z.
#
# Similarly, T-gate induces a 𝜋/4 phase, and it is called $\sqrt[4]{Z}$ gate.

# %%
simulator = Aer.get_backend('statevector_simulator')
sv = Statevector.from_label('0')
plot_state_qsphere(sv.data)
plot_bloch_multivector(sv)
#job = execute(qc, simulator)
#result = job.result()
#outputstate = result.get_statevector(qc)
#plot_bloch_multivector(outputstate)
