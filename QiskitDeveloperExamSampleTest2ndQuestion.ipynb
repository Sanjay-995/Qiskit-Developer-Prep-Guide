# %% [markdown]
# # IBM Certified Associate Developer-Qiksit v0.2X Sample Test 2nd Question

# %% [markdown]
# ## Import all packages

# %%
from qiskit import IBMQ, QuantumRegister, ClassicalRegister, QuantumCircuit, Aer, execute

from qiskit.quantum_info import Statevector

from qiskit.visualization import plot_bloch_multivector, plot_histogram

import numpy as np
from numpy import pi
import math
from math import sqrt

import matplotlib as mpl
# %matplotlib inline

# %% [markdown]
# ## Rotation Gate
#
# Given the code fragment as follow, we need to find the probabiliy that a measurement would result in |0>.

# %%
qc = QuantumCircuit(1)

# %%
qc.draw(output="mpl")

# %%
# Bloch Sphere

simulator_statevector = Aer.get_backend('statevector_simulator')
job_statevector = execute(qc, simulator_statevector)
result_statevector = job_statevector.result()
outputstate = result_statevector.get_statevector(qc)
plot_bloch_multivector(outputstate)
# Out:
# /Users/callmehandsome/opt/anaconda3/lib/python3.8/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
qc.ry(3 * math.pi/4, 0)

# %%
qc.draw(output="mpl")

# %%
qc = QuantumCircuit(2)

# %%
qc.ry(3 * math.pi/4, 1)

# %%
qc.draw(output="mpl")

# %%
# Bloch Sphere

simulator_statevector = Aer.get_backend('statevector_simulator')
job_statevector = execute(qc, simulator_statevector)
result_statevector = job_statevector.result()
outputstate = result_statevector.get_statevector(qc)
plot_bloch_multivector(outputstate)
# Out:
# /Users/callmehandsome/opt/anaconda3/lib/python3.8/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
qc_rotate = QuantumCircuit(1, 1)
qc_rotate.ry(3 * math.pi/4, 0)

# %%
qc_rotate.measure([0], [0])

# %%
qc_rotate.draw(output="mpl")

# %%
# Use Aer's qasm_simulator
simulator = Aer.get_backend('qasm_simulator')
# Execute the circuit on the qasm simulator
job = execute(qc_rotate, simulator, shots=1000)
# Grab results from the job
result = job.result()
# Returns counts
counts = result.get_counts(qc_rotate)
print("\nTotal count for 0 and 1 are:",counts)
# Out:
# Total count for 0 and 1 are: {'1': 1000}

# %%
# Plot a histogram
plot_histogram(counts)

# %% [markdown]
# The result for |0> should be between 0.13-0.16.

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Option A

# %% [markdown]
# 0.8536

# %%
qc_rotate = QuantumCircuit(1, 1)
qc_rotate.ry(math.pi/4, 0)

# %%
qc_rotate.measure([0], [0])

# %%
qc_rotate.draw(output="mpl")

# %%
# Use Aer's qasm_simulator
simulator = Aer.get_backend('qasm_simulator')
# Execute the circuit on the qasm simulator
job = execute(qc_rotate, simulator, shots=1000)
# Grab results from the job
result = job.result()
# Returns counts
counts = result.get_counts(qc_rotate)
print("\nTotal count for 0 and 1 are:",counts)
# Out:
# Total count for 0 and 1 are: {'1': 142, '0': 858}

# %%
# Plot a histogram
plot_histogram(counts)

# %% [markdown]
# ### Option B

# %% [markdown]
# 0.5

# %%
qc_rotate = QuantumCircuit(1, 1)
qc_rotate.ry(math.pi/2, 0)

# %%
qc_rotate.measure([0], [0])

# %%
qc_rotate.draw(output="mpl")

# %%
# Use Aer's qasm_simulator
simulator = Aer.get_backend('qasm_simulator')
# Execute the circuit on the qasm simulator
job = execute(qc_rotate, simulator, shots=1000)
# Grab results from the job
result = job.result()
# Returns counts
counts = result.get_counts(qc_rotate)
print("\nTotal count for 0 and 1 are:",counts)
# Out:
# Total count for 0 and 1 are: {'1': 498, '0': 502}

# %%
# Plot a histogram
plot_histogram(counts)

# %% [markdown]
# ### Option C

# %% [markdown]
# 0.1464

# %%
qc_rotate = QuantumCircuit(1, 1)
qc_rotate.ry(3 * math.pi/4, 0)

# %%
qc_rotate.measure([0], [0])

# %%
qc_rotate.draw(output="mpl")

# %%
# Use Aer's qasm_simulator
simulator = Aer.get_backend('qasm_simulator')
# Execute the circuit on the qasm simulator
job = execute(qc_rotate, simulator, shots=1000)
# Grab results from the job
result = job.result()
# Returns counts
counts = result.get_counts(qc_rotate)
print("\nTotal count for 0 and 1 are:",counts)
# Out:
# Total count for 0 and 1 are: {'1': 863, '0': 137}

# %%
# Plot a histogram
plot_histogram(counts)

# %% [markdown]
# ### Option D

# %% [markdown]
# 1.0

# %%
qc_rotate = QuantumCircuit(1, 1)
qc_rotate.ry(math.pi, 0)

# %%
qc_rotate.measure([0], [0])

# %%
qc_rotate.draw(output="mpl")

# %%
# Use Aer's qasm_simulator
simulator = Aer.get_backend('qasm_simulator')
# Execute the circuit on the qasm simulator
job = execute(qc_rotate, simulator, shots=1000)
# Grab results from the job
result = job.result()
# Returns counts
counts = result.get_counts(qc_rotate)
print("\nTotal count for 0 and 1 are:",counts)
# Out:
# Total count for 0 and 1 are: {'1': 1000}

# %%
# Plot a histogram
plot_histogram(counts)

# %% [markdown]
# # Reference

# %% [markdown]
# $R_y$ Gate from Qiskit
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.RYGate.html

# %% [markdown]
# Bloch Vector from Qiskit
# https://qiskit.org/documentation/stubs/qiskit.visualization.plot_bloch_vector.html

# %% [markdown]
# Mid-Circuit Measurements Tutorial from Qiskit
# https://quantum-computing.ibm.com/lab/docs/iql/manage/systems/midcircuit-measurement/

# %% [markdown]
# QASM Simulator from Qiskit
# https://qiskit.org/documentation/stubs/qiskit.providers.aer.QasmSimulator.html
