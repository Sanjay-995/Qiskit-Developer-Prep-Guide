# %% [markdown]
# # Question 6: Answers are A and C.
#
# There are two method to get to x, think about the rotation to do this question

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, Aer, execute

from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector, plot_histogram

import numpy as np
from numpy import pi
import math
from math import sqrt

import matplotlib as mpl
# %matplotlib inline

# %% [markdown]
# ## Option A

# %%
qc = QuantumCircuit(1,1)
qc.h(0)

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(qc, simulator)
result = job.result()
outputstate = result.get_statevector(qc)
plot_bloch_multivector(outputstate)
# Out:
# /Users/callmehandsome/opt/anaconda3/lib/python3.8/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ## Option C

# %%
qc = QuantumCircuit(1,1)
# Insert code fragment here
qc.ry(math.pi / 2, 0)

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(qc, simulator)
result = job.result()
outputstate = result.get_statevector(qc)
plot_bloch_multivector(outputstate)
# Out:
# /Users/callmehandsome/opt/anaconda3/lib/python3.8/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# # For Option B, D and E

# %% [markdown]
# ## Option B

# %%
qc = QuantumCircuit(1,1)
# Insert code fragment here
qc.rx(math.pi / 2, 0)

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(qc, simulator)
result = job.result()
outputstate = result.get_statevector(qc)
plot_bloch_multivector(outputstate)
# Out:
# /Users/callmehandsome/opt/anaconda3/lib/python3.8/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ## Option D

# %%
qc = QuantumCircuit(1,1)
# Insert code fragment here
qc.rx(math.pi / 2, 0)
qc.rz(-math.pi / 2, 0)

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(qc, simulator)
result = job.result()
outputstate = result.get_statevector(qc)
plot_bloch_multivector(outputstate)
# Out:
# /Users/callmehandsome/opt/anaconda3/lib/python3.8/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ## Option E

# %%
qc = QuantumCircuit(1,1)
# Insert code fragment here
qc.ry(math.pi, 0)

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(qc, simulator)
result = job.result()
outputstate = result.get_statevector(qc)
plot_bloch_multivector(outputstate)
# Out:
# /Users/callmehandsome/opt/anaconda3/lib/python3.8/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
